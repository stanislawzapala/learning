# %%
from collections import deque

queue = deque([1, 2, 3])

# %%
print(queue)
# Out:
# deque([1, 2, 3])

# %%
came_from = {1: None}
print(came_from)
# Out:
# {1: None}

# %%
curr = queue.popleft()
print(curr)
# Out:
# 1

# %%
bool(queue)
# Out:
# True
